# %% [markdown]
# # GaussianNB

# %% [markdown]
# ### This algorithm  use for handle numerical data and categorial data
#
# ### output is 0 and 1 / yes or no
#
# ### if problem has numeric data at that time we use probability normal/Gaussian distribution formula
#
# ### most improtant is sklearn GaussianNB class use probability normal/Gaussian distribution formula for training

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('

# %%
df.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df.drop(columns=['day'],inplace=True)

# %%
df.head()
# Out:
#     outlook  temp humidity    wind play
# 0     Sunny   Hot     High    Weak   No
# 1     Sunny   Hot     High  Strong   No
# 2  Overcast   Hot     High    Weak  Yes
# 3      Rain  Mild     High    Weak  Yes
# 4      Rain  Cool   Normal    Weak  Yes

# %%
df['outlook'].value_counts()
# Out:
# outlook
# Sunny       5
# Rain        5
# Overcast    4
# Name: count, dtype: int64

# %%
df['outlook']=df['outlook'].map({'Sunny':0,'Rain':1,'Overcast':2})

# %%
df['temp'].value_counts()
# Out:
# temp
# Mild    6
# Hot     4
# Cool    4
# Name: count, dtype: int64

# %%
df['temp'] = df['temp'].map({'Mild' :0 ,'Hot':1,'Cool':4})

# %%
df['humidity'].value_counts()
# Out:
# humidity
# High      7
# Normal    7
# Name: count, dtype: int64

# %%
df['humidity']=df['humidity'].map({'High':0,'Normal':1})

# %%
df['wind'].value_counts()
# Out:
# wind
# Weak      8
# Strong    6
# Name: count, dtype: int64

# %%
df['wind']=df['wind'].map({'Weak':0,'Strong':1})

# %%
df['play'] = df['play'].map({'No' :0,'Yes':1})

# %%
df.dtypes
# Out:
# outlook     int64
# temp        int64
# humidity    int64
# wind        int64
# play        int64
# dtype: object

# %%
x = df.iloc[:,:-1]
x
# Out:
#     outlook  temp  humidity  wind
# 0         0     1         0     0
# 1         0     1         0     1
# 2         2     1         0     0
# 3         1     0         0     0
# 4         1     4         1     0
# 5         1     4         1     1
# 6         2     4         1     1
# 7         0     0         0     0
# 8         0     4         1     0
# 9         1     0         1     0
# 10        0     0         1     1
# 11        2     0         0     1
# 12        2     1         1     0
# 13        1     0         0     1

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: play, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train ,y_train)
# Out:
# GaussianNB()

# %%
gnb.predict(x_test.iloc[0:1,:])
# Out:
# array([1], dtype=int64)

# %%
x_test
# Out:
#     outlook  temp  humidity  wind
# 9         1     0         1     0
# 11        2     0         0     1
# 0         0     1         0     0

# %%
y_test
# Out:
# 9     1
# 11    1
# 0     0
# Name: play, dtype: int64
