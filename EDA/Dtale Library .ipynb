# %%
# !pip install dtale
# Out:
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ------------------------------------- 642.7/642.7 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#    ---------------------------------------- 0.0/17.6 MB ? eta -:--:--
#    -------- ------------------------------- 3.9/17.6 MB 19.6 MB/s eta 0:00:01
#    -------------- ------------------------- 6.6/17.6 MB 15.5 MB/s eta 0:00:01
#    -------------------- ------------------- 9.2/17.6 MB 14.3 MB/s eta 0:00:01
#    -------------------------- ------------- 11.5/17.6 MB 13.9 MB/s eta 0:00:01
#    -------------------------------- ------- 14.2/17.6 MB 13.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.7/17.6 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 17.6/17.6 MB 12.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

import dtale
# Out:
# D:\anaconda\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
